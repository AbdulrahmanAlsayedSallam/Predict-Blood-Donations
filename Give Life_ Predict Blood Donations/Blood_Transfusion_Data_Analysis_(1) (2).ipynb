# %% [markdown]
# ## 1. Inspecting transfusion.data file
# <p><img src="https://assets.datacamp.com/production/project_646/img/blood_donation.png" style="float: right;" alt="A pictogram of a blood bag with blood donation written in it" width="200"></p>
# <p>Blood transfusion saves lives - from replacing lost blood during major surgery or a serious injury to treating various illnesses and blood disorders. Ensuring that there's enough blood in supply whenever needed is a serious challenge for the health professionals. According to <a href="https://www.webmd.com/a-to-z-guides/blood-transfusion-what-to-know#1">WebMD</a>, "about 5 million Americans need a blood transfusion every year".</p>
# <p>Our dataset is from a mobile blood donation vehicle in Taiwan. The Blood Transfusion Service Center drives to different universities and collects blood as part of a blood drive. We want to predict whether or not a donor will give blood the next time the vehicle comes to campus.</p>
# <p>The data is stored in <code>datasets/transfusion.data</code> and it is structured according to RFMTC marketing model (a variation of RFM). We'll explore what that means later in this notebook. First, let's inspect the data.</p>

# %%
# Print out the first 5 lines from the transfusion.data file
# !head -n 5 transfusion.data
# Out:
# Recency (months),Frequency (times),Monetary (c.c. blood),Time (months),"whether he/she donated blood in March 2007"
# 2 ,50,12500,98 ,1
# 0 ,13,3250,28 ,1
# 1 ,16,4000,35 ,1
# 2 ,20,5000,45 ,1

# %% [markdown]
# ## 2. Loading the blood donations data
# <p>We now know that we are working with a typical CSV file (i.e., the delimiter is <code>,</code>, etc.). We proceed to loading the data into memory.</p>

# %%
# Import pandas
import pandas as pd

# Read in dataset
transfusion = pd.read_csv('transfusion.data')
# Print out the first rows of our dataset
# ... YOUR CODE FOR TASK 2 ...
transfusion.head(1)
# Out:
#    Recency (months)  Frequency (times)  Monetary (c.c. blood)  Time (months)  \
# 0                 2                 50                  12500             98
#
#    whether he/she donated blood in March 2007
# 0                                           1

# %% [markdown]
# ## 3. Inspecting transfusion DataFrame
# <p>Let's briefly return to our discussion of RFM model. RFM stands for Recency, Frequency and Monetary Value and it is commonly used in marketing for identifying your best customers. In our case, our customers are blood donors.</p>
# <p>RFMTC is a variation of the RFM model. Below is a description of what each column means in our dataset:</p>
# <ul>
# <li>R (Recency - months since the last donation)</li>
# <li>F (Frequency - total number of donation)</li>
# <li>M (Monetary - total blood donated in c.c.)</li>
# <li>T (Time - months since the first donation)</li>
# <li>a binary variable representing whether he/she donated blood in March 2007 (1 stands for donating blood; 0 stands for not donating blood)</li>
# </ul>
# <p>It looks like every column in our DataFrame has the numeric type, which is exactly what we want when building a machine learning model. Let's verify our hypothesis.</p>

# %%
# Print a concise summary of transfusion DataFrame
# ... YOUR CODE FOR TASK 3 ...
transfusion.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 748 entries, 0 to 747
# Data columns (total 5 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Recency (months)                            748 non-null    int64
#  1   Frequency (times)                           748 non-null    int64
#  2   Monetary (c.c. blood)                       748 non-null    int64
#  3   Time (months)                               748 non-null    int64
#  4   whether he/she donated blood in March 2007  748 non-null    int64
# dtypes: int64(5)
# memory usage: 29.3 KB

# %% [markdown]
# All columns in the transfusion dataset are numeric (int64), which is ideal for machine learning models such as logistic regression. There are no missing values, and each feature aligns with the RFMTC model (Recency, Frequency, Monetary, Time, and the Target variable). The DataFrame contains 748 rows and 5 columns, confirming the dataset loaded correctly.

# %% [markdown]
# ## 4. Creating target column
# <p>We are aiming to predict the value in <code>whether he/she donated blood in March 2007</code> column. Let's rename this it to <code>target</code> so that it's more convenient to work with.</p>

# %%
# Rename target column as 'target' for brevity
transfusion.rename(
    columns={'whether he/she donated blood in March 2007': 'target'},
    inplace=True
)

# Print out the first 2 rows
# ... YOUR CODE FOR TASK 4 ...
transfusion.head(2)
# Out:
#    Recency (months)  Frequency (times)  Monetary (c.c. blood)  Time (months)  \
# 0                 2                 50                  12500             98
# 1                 0                 13                   3250             28
#
#    target
# 0       1
# 1       1

# %% [markdown]
# ## 5. Checking target incidence
# <p>We want to predict whether or not the same donor will give blood the next time the vehicle comes to campus. The model for this is a binary classifier, meaning that there are only 2 possible outcomes:</p>
# <ul>
# <li><code>0</code> - the donor will not give blood</li>
# <li><code>1</code> - the donor will give blood</li>
# </ul>
# <p>Target incidence is defined as the number of cases of each individual target value in a dataset. That is, how many 0s in the target column compared to how many 1s? Target incidence gives us an idea of how balanced (or imbalanced) is our dataset.</p>

# %%
# Print target incidence proportions, rounding output to 3 decimal places
# ... YOUR CODE FOR TASK 5 ...
# Print target incidence proportions, rounded to 3 decimal places
target_incidence = transfusion['target'].value_counts(normalize=True).round(3)
print(target_incidence)
# Out:
# target
# 0    0.762
# 1    0.238
# Name: proportion, dtype: float64

# %% [markdown]
# The target incidence output shows that approximately 76.2% of donors did not give blood next time (0), while only 23.8% did (1). This indicates that the dataset is imbalanced, with many more cases of non-donors than donors.

# %% [markdown]
# ## 6. Splitting transfusion into train and test datasets
# <p>We'll now use <code>train_test_split()</code> method to split <code>transfusion</code> DataFrame.</p>
# <p>Target incidence informed us that in our dataset <code>0</code>s appear 76% of the time. We want to keep the same structure in train and test datasets, i.e., both datasets must have 0 target incidence of 76%. This is very easy to do using the <code>train_test_split()</code> method from the <code>scikit learn</code> library - all we need to do is specify the <code>stratify</code> parameter. In our case, we'll stratify on the <code>target</code> column.</p>

# %%
# Import train_test_split method
from sklearn.model_selection import train_test_split

# Split transfusion DataFrame into
# X_train, X_test, y_train and y_test datasets,
# stratifying on the `target` column
X_train, X_test, y_train, y_test = train_test_split = train_test_split(
    transfusion.drop(columns='target'),
    transfusion.target,
    test_size=0.25,
    random_state=42,
    stratify=transfusion['target']
)

# Print out the first 2 rows of X_train
# ... YOUR CODE FOR TASK 6 ...
print(X_train.head(2))
# Out:
#      Recency (months)  Frequency (times)  Monetary (c.c. blood)  Time (months)
# 334                16                  2                    500             16
# 99                  5                  7                   1750             26

# %% [markdown]
# ## 7. Selecting model using TPOT
# <p><a href="https://github.com/EpistasisLab/tpot">TPOT</a> is a Python Automated Machine Learning tool that optimizes machine learning pipelines using genetic programming.</p>
# <p><img src="https://assets.datacamp.com/production/project_646/img/tpot-ml-pipeline.png" alt="TPOT Machine Learning Pipeline"></p>
# <p>TPOT will automatically explore hundreds of possible pipelines to find the best one for our dataset. Note, the outcome of this search will be a <a href="https://scikit-learn.org/stable/modules/generated/sklearn.pipeline.Pipeline.html">scikit-learn pipeline</a>, meaning it will include any pre-processing steps as well as the model.</p>
# <p>We are using TPOT to help us zero in on one model that we can then explore and optimize further.</p>

# %%
pip install git+https://github.com/EpistasisLab/tpot.git
# Out:
# Collecting git+https://github.com/EpistasisLab/tpot.git
#   Cloning https://github.com/EpistasisLab/tpot.git to /tmp/pip-req-build-0kn4ry0h
#   Running command git clone --filter=blob:none --quiet https://github.com/EpistasisLab/tpot.git /tmp/pip-req-build-0kn4ry0h
#   Resolved https://github.com/EpistasisLab/tpot.git to commit 1bca6c6a51a79dc7370fbd2a8864a561fc5d7529
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy>=1.26.4 in /usr/local/lib/python3.12/dist-packages (from TPOT==1.1.1.dev9+g1bca6c6a5) (2.0.2)
# Requirement already satisfied: scipy>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from TPOT==1.1.1.dev9+g1bca6c6a5) (1.16.3)
# Requirement already satisfied: scikit-learn>=1.6 in /usr/local/lib/python3.12/dist-packages (from TPOT==1.1.1.dev9+g1bca6c6a5) (1.6.1)
# Collecting update_checker>=0.16 (from TPOT==1.1.1.dev9+g1bca6c6a5)
#   Downloading update_checker-0.18.0-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: tqdm>=4.36.1 in /usr/local/lib/python3.12/dist-packages (from TPOT==1.1.1.dev9+g1bca6c6a5) (4.67.1)
# Collecting stopit>=1.1.1 (from TPOT==1.1.1.dev9+g1bca6c6a5)
#   Downloading stopit-1.1.2.tar.gz (18 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from TPOT==1.1.1.dev9+g1bca6c6a5) (2.2.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from TPOT==1.1.1.dev9+g1bca6c6a5) (1.5.2)
# Requirement already satisfied: xgboost>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from TPOT==1.1.1.dev9+g1bca6c6a5) (3.1.1)
# Requirement already satisfied: matplotlib>=3.6.2 in /usr/local/lib/python3.12/dist-packages (from TPOT==1.1.1.dev9+g1bca6c6a5) (3.10.0)
# Collecting traitlets>=5.8.0 (from TPOT==1.1.1.dev9+g1bca6c6a5)
#   Downloading traitlets-5.14.3-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: lightgbm>=3.3.3 in /usr/local/lib/python3.12/dist-packages (from TPOT==1.1.1.dev9+g1bca6c6a5) (4.6.0)
# Collecting optuna>=3.0.5 (from TPOT==1.1.1.dev9+g1bca6c6a5)
#   Downloading optuna-4.6.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.12/dist-packages (from TPOT==1.1.1.dev9+g1bca6c6a5) (3.5)
# Requirement already satisfied: dask>=2024.4.2 in /usr/local/lib/python3.12/dist-packages (from TPOT==1.1.1.dev9+g1bca6c6a5) (2025.9.1)
# Requirement already satisfied: distributed>=2024.4.2 in /usr/local/lib/python3.12/dist-packages (from TPOT==1.1.1.dev9+g1bca6c6a5) (2025.9.1)
# Collecting dask-expr>=1.0.12 (from TPOT==1.1.1.dev9+g1bca6c6a5)
#   Downloading dask_expr-2.0.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting dask-jobqueue>=0.8.5 (from TPOT==1.1.1.dev9+g1bca6c6a5)
#   Downloading dask_jobqueue-0.9.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Collecting func_timeout>=4.3.5 (from TPOT==1.1.1.dev9+g1bca6c6a5)
#   Downloading func_timeout-4.3.5.tar.gz (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 2.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting configspace>=1.1.1 (from TPOT==1.1.1.dev9+g1bca6c6a5)
#   Downloading configspace-1.2.1.tar.gz (130 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.0/131.0 kB 5.5 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting dill>=0.3.9 (from TPOT==1.1.1.dev9+g1bca6c6a5)
#   Downloading dill-0.4.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: seaborn>=0.13.2 in /usr/local/lib/python3.12/dist-packages (from TPOT==1.1.1.dev9+g1bca6c6a5) (0.13.2)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.12/dist-packages (from configspace>=1.1.1->TPOT==1.1.1.dev9+g1bca6c6a5) (3.2.5)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.12/dist-packages (from configspace>=1.1.1->TPOT==1.1.1.dev9+g1bca6c6a5) (4.15.0)
# Requirement already satisfied: more_itertools in /usr/local/lib/python3.12/dist-packages (from configspace>=1.1.1->TPOT==1.1.1.dev9+g1bca6c6a5) (10.8.0)
# Requirement already satisfied: click>=8.1 in /usr/local/lib/python3.12/dist-packages (from dask>=2024.4.2->TPOT==1.1.1.dev9+g1bca6c6a5) (8.3.1)
# Requirement already satisfied: cloudpickle>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from dask>=2024.4.2->TPOT==1.1.1.dev9+g1bca6c6a5) (3.1.2)
# Requirement already satisfied: fsspec>=2021.09.0 in /usr/local/lib/python3.12/dist-packages (from dask>=2024.4.2->TPOT==1.1.1.dev9+g1bca6c6a5) (2025.3.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from dask>=2024.4.2->TPOT==1.1.1.dev9+g1bca6c6a5) (25.0)
# Requirement already satisfied: partd>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from dask>=2024.4.2->TPOT==1.1.1.dev9+g1bca6c6a5) (1.4.2)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.12/dist-packages (from dask>=2024.4.2->TPOT==1.1.1.dev9+g1bca6c6a5) (6.0.3)
# Requirement already satisfied: toolz>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from dask>=2024.4.2->TPOT==1.1.1.dev9+g1bca6c6a5) (0.12.1)
# Requirement already satisfied: jinja2>=2.10.3 in /usr/local/lib/python3.12/dist-packages (from distributed>=2024.4.2->TPOT==1.1.1.dev9+g1bca6c6a5) (3.1.6)
# Requirement already satisfied: locket>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from distributed>=2024.4.2->TPOT==1.1.1.dev9+g1bca6c6a5) (1.0.0)
# Requirement already satisfied: msgpack>=1.0.2 in /usr/local/lib/python3.12/dist-packages (from distributed>=2024.4.2->TPOT==1.1.1.dev9+g1bca6c6a5) (1.1.2)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.12/dist-packages (from distributed>=2024.4.2->TPOT==1.1.1.dev9+g1bca6c6a5) (5.9.5)
# Requirement already satisfied: sortedcontainers>=2.0.5 in /usr/local/lib/python3.12/dist-packages (from distributed>=2024.4.2->TPOT==1.1.1.dev9+g1bca6c6a5) (2.4.0)
# Requirement already satisfied: tblib>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from distributed>=2024.4.2->TPOT==1.1.1.dev9+g1bca6c6a5) (3.2.2)
# Requirement already satisfied: tornado>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from distributed>=2024.4.2->TPOT==1.1.1.dev9+g1bca6c6a5) (6.5.1)
# Requirement already satisfied: urllib3>=1.26.5 in /usr/local/lib/python3.12/dist-packages (from distributed>=2024.4.2->TPOT==1.1.1.dev9+g1bca6c6a5) (2.5.0)
# Requirement already satisfied: zict>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from distributed>=2024.4.2->TPOT==1.1.1.dev9+g1bca6c6a5) (3.0.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6.2->TPOT==1.1.1.dev9+g1bca6c6a5) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6.2->TPOT==1.1.1.dev9+g1bca6c6a5) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6.2->TPOT==1.1.1.dev9+g1bca6c6a5) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6.2->TPOT==1.1.1.dev9+g1bca6c6a5) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6.2->TPOT==1.1.1.dev9+g1bca6c6a5) (11.3.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6.2->TPOT==1.1.1.dev9+g1bca6c6a5) (2.9.0.post0)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from optuna>=3.0.5->TPOT==1.1.1.dev9+g1bca6c6a5) (1.17.2)
# Collecting colorlog (from optuna>=3.0.5->TPOT==1.1.1.dev9+g1bca6c6a5)
#   Downloading colorlog-6.10.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from optuna>=3.0.5->TPOT==1.1.1.dev9+g1bca6c6a5) (2.0.44)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.2.0->TPOT==1.1.1.dev9+g1bca6c6a5) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.2.0->TPOT==1.1.1.dev9+g1bca6c6a5) (2025.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.6->TPOT==1.1.1.dev9+g1bca6c6a5) (3.6.0)
# Requirement already satisfied: requests>=2.3.0 in /usr/local/lib/python3.12/dist-packages (from update_checker>=0.16->TPOT==1.1.1.dev9+g1bca6c6a5) (2.32.4)
# Requirement already satisfied: nvidia-nccl-cu12 in /usr/local/lib/python3.12/dist-packages (from xgboost>=3.0.0->TPOT==1.1.1.dev9+g1bca6c6a5) (2.27.5)
# Requirement already satisfied: Mako in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna>=3.0.5->TPOT==1.1.1.dev9+g1bca6c6a5) (1.3.10)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2>=2.10.3->distributed>=2024.4.2->TPOT==1.1.1.dev9+g1bca6c6a5) (3.0.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.6.2->TPOT==1.1.1.dev9+g1bca6c6a5) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.3.0->update_checker>=0.16->TPOT==1.1.1.dev9+g1bca6c6a5) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.3.0->update_checker>=0.16->TPOT==1.1.1.dev9+g1bca6c6a5) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.3.0->update_checker>=0.16->TPOT==1.1.1.dev9+g1bca6c6a5) (2025.11.12)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.4.2->optuna>=3.0.5->TPOT==1.1.1.dev9+g1bca6c6a5) (3.2.4)
# Downloading dask_expr-2.0.0-py3-none-any.whl (3.2 kB)
# Downloading dask_jobqueue-0.9.0-py2.py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.0/52.0 kB 3.9 MB/s eta 0:00:00
# Downloading dill-0.4.0-py3-none-any.whl (119 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.7/119.7 kB 9.7 MB/s eta 0:00:00
# Downloading optuna-4.6.0-py3-none-any.whl (404 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 404.7/404.7 kB 19.6 MB/s eta 0:00:00
# Downloading traitlets-5.14.3-py3-none-any.whl (85 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.4/85.4 kB 6.2 MB/s eta 0:00:00
# Downloading update_checker-0.18.0-py3-none-any.whl (7.0 kB)
# Downloading colorlog-6.10.1-py3-none-any.whl (11 kB)
# Building wheels for collected packages: TPOT, configspace, func_timeout, stopit
#   Building wheel for TPOT (pyproject.toml) ... done
#   Created wheel for TPOT: filename=tpot-1.1.1.dev9+g1bca6c6a5-py3-none-any.whl size=224702 sha256=5924637a3ae07db7a3c10d4891a76aaeceb73645d2dd4bba8671d63082529ecb
#   Stored in directory: /tmp/pip-ephem-wheel-cache-uf6kb1kp/wheels/ae/d1/04/06c02cb20e6feda22faba579168a7e39083575c99e7b81c57f
#   Building wheel for configspace (pyproject.toml) ... done
#   Created wheel for configspace: filename=configspace-1.2.1-py3-none-any.whl size=115990 sha256=75e744e1ce0cb16a59abfab3c45f3a55b16650684ebf028317374d1450cb195a
#   Stored in directory: /root/.cache/pip/wheels/bb/a5/10/517a06ebdda14bf732250e82f8ba212a73bf88a8fc675ea2ef
#   Building wheel for func_timeout (setup.py) ... done
#   Created wheel for func_timeout: filename=func_timeout-4.3.5-py3-none-any.whl size=15077 sha256=83c344666f0840de21c5028b158f534ce3bdbbe528d95367e14cf718de1613e1
#   Stored in directory: /root/.cache/pip/wheels/ed/94/4a/9ccd71f7284a92e4137b7dd0ce8540c40ea7c2689251504a49
#   Building wheel for stopit (setup.py) ... done
#   Created wheel for stopit: filename=stopit-1.1.2-py3-none-any.whl size=11938 sha256=1693ec21f934ad19d28633e9080059fec7de5d8d0c7d8b08c466c3ed7bf4ced6
#   Stored in directory: /root/.cache/pip/wheels/10/10/63/c3c98c9859d2aa59553536cc2ea005d3c9c39e214ab4fd614c
# Successfully built TPOT configspace func_timeout stopit
# Installing collected packages: stopit, func_timeout, traitlets, dill, colorlog, update_checker, configspace, optuna, dask-expr, dask-jobqueue, TPOT
#   Attempting uninstall: traitlets
#     Found existing installation: traitlets 5.7.1
#     Uninstalling traitlets-5.7.1:
#       Successfully uninstalled traitlets-5.7.1
#   Attempting uninstall: dill
#     Found existing installation: dill 0.3.8
#     Uninstalling dill-0.3.8:
#       Successfully uninstalled dill-0.3.8
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# datasets 4.0.0 requires dill<0.3.9,>=0.3.0, but you have dill 0.4.0 which is incompatible.
# Successfully installed TPOT-1.1.1.dev9+g1bca6c6a5 colorlog-6.10.1 configspace-1.2.1 dask-expr-2.0.0 dask-jobqueue-0.9.0 dill-0.4.0 func_timeout-4.3.5 optuna-4.6.0 stopit-1.1.2 traitlets-5.14.3 update_checker-0.18.0

# %%
import tpot
print(tpot.__version__)
# Out:
# 1.1.1.dev9+g1bca6c6a5

# %% [markdown]
# **Note:** The TPOT 1.1.1.dev version installed in this environment (required for Python 3.12 compatibility) does not support passing scoring or disable_update_check or config_dict directly to TPOTClassifier as in earlier versions. Therefore, the ROC AUC score is computed manually after fitting the model.

# %%
# Import TPOTClassifier and roc_auc_score
from tpot import TPOTClassifier
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import StratifiedKFold

# Instantiate TPOTClassifier (no changes made)
tpot = TPOTClassifier(
    generations=5,
    population_size=20,
    random_state=42,
    cv=StratifiedKFold(n_splits=5, shuffle=True, random_state=42),
    n_jobs=1,
    verbose=2,
)

# Fit model
tpot.fit(X_train, y_train)

# AUC score for tpot model
tpot_auc_score = roc_auc_score(y_test, tpot.predict_proba(X_test)[:, 1])
print(f'\nAUC score: {tpot_auc_score:.4f}')

# Print best pipeline steps
print('\nBest pipeline steps:', end='\n')
for idx, (name, transform) in enumerate(tpot.fitted_pipeline_.steps, start=1):
    print(f'{idx}. {transform}')
# Out:
# /usr/local/lib/python3.12/dist-packages/tpot/tpot_estimator/estimator.py:458: UserWarning: Both generations and max_time_mins are set. TPOT will terminate when the first condition is met.
#   warnings.warn("Both generations and max_time_mins are set. TPOT will terminate when the first condition is met.")
# INFO:distributed.scheduler:State start
# INFO:distributed.scheduler:  Scheduler at:     tcp://127.0.0.1:43283
# INFO:distributed.scheduler:  dashboard at:  http://127.0.0.1:8787/status
# INFO:distributed.scheduler:Registering Worker plugin shuffle
# INFO:distributed.nanny:        Start Nanny at: 'tcp://127.0.0.1:43929'
# INFO:distributed.scheduler:Register worker addr: tcp://127.0.0.1:46589 name: 0
# INFO:distributed.scheduler:Starting worker compute stream, tcp://127.0.0.1:46589
# INFO:distributed.core:Starting established connection to tcp://127.0.0.1:45850
# INFO:distributed.scheduler:Receive client connection: Client-42bcc1fa-c8a5-11f0-8343-0242ac1c000c
# INFO:distributed.core:Starting established connection to tcp://127.0.0.1:45862
# Generation: 100%|██████████| 5/5 [03:09<00:00, 37.95s/it]
# INFO:distributed.scheduler:Retire worker addresses (stimulus_id='retire-workers-1763927448.5827963') (0,)
# INFO:distributed.nanny:Closing Nanny at 'tcp://127.0.0.1:43929'. Reason: nanny-close
# INFO:distributed.nanny:Nanny asking worker to close. Reason: nanny-close
# INFO:distributed.core:Received 'close-stream' from tcp://127.0.0.1:45850; closing.
# INFO:distributed.scheduler:Remove worker addr: tcp://127.0.0.1:46589 name: 0 (stimulus_id='handle-worker-cleanup-1763927448.5903728')
# ERROR:distributed.scheduler:Removing worker 'tcp://127.0.0.1:46589' caused the cluster to lose scattered data, which can't be recovered: {'DataFrame-e5f62a0fb98ea518b6b622cab1f356a9', 'Series-f17916ec5cc2951ecbc1471e25663f27'} (stimulus_id='handle-worker-cleanup-1763927448.5903728')
# INFO:distributed.scheduler:Lost all workers
# INFO:distributed.nanny:Nanny at 'tcp://127.0.0.1:43929' closed.
# INFO:distributed.scheduler:Closing scheduler. Reason: unknown
# INFO:distributed.scheduler:Scheduler closing all comms
# AUC score: 0.7669
#
# Best pipeline steps:
# 1. Normalizer(norm=np.str_('max'))
# 2. Passthrough()
# 3. FeatureUnion(transformer_list=[('skiptransformer', SkipTransformer()),
#                                ('passthrough', Passthrough())])
# 4. FeatureUnion(transformer_list=[('skiptransformer', SkipTransformer()),
#                                ('passthrough', Passthrough())])
# 5. AdaBoostClassifier(learning_rate=0.27687721667, n_estimators=314,
#                    random_state=42)

# %% [markdown]
# ## 8. Checking the variance
# <p>TPOT picked <code>LogisticRegression</code> as the best model for our dataset with no pre-processing steps, giving us the AUC score of 0.7850. This is a great starting point. Let's see if we can make it better.</p>
# <p>One of the assumptions for linear regression models is that the data and the features we are giving it are related in a linear fashion, or can be measured with a linear distance metric. If a feature in our dataset has a high variance that's an order of magnitude or more greater than the other features, this could impact the model's ability to learn from other features in the dataset.</p>
# <p>Correcting for high variance is called normalization. It is one of the possible transformations you do before training a model. Let's check the variance to see if such transformation is needed.</p>

# %%
# X_train's variance, rounding the output to 3 decimal places
# ... YOUR CODE FOR TASK 8 ...
variance = X_train.var().round(3)
print(variance)
# Out:
# Recency (months)              66.929
# Frequency (times)             33.830
# Monetary (c.c. blood)    2114363.700
# Time (months)                611.147
# dtype: float64

# %% [markdown]
# ## 9. Log normalization
# <p><code>Monetary (c.c. blood)</code>'s variance is very high in comparison to any other column in the dataset. This means that, unless accounted for, this feature may get more weight by the model (i.e., be seen as more important) than any other feature.</p>
# <p>One way to correct for high variance is to use log normalization.</p>

# %%
# Import numpy
import numpy as np

# Copy X_train and X_test into X_train_normed and X_test_normed
X_train_normed, X_test_normed = X_train.copy(), X_test.copy()

# Specify which column has the highest variance
col_to_normalize = X_train.var().idxmax()

# Log normalization
for df_ in [X_train_normed, X_test_normed]:
    # Add log normalized column
    df_['monetary_log'] = np.log(df_[col_to_normalize])
    # Drop the original column
    df_.drop(columns=col_to_normalize, inplace=True)

# Check the variance for X_train_normed
X_train_normed.var().round(3)
# Out:
# Recency (months)      66.929
# Frequency (times)     33.830
# Time (months)        611.147
# monetary_log           0.837
# dtype: float64

# %% [markdown]
# ## 10. Training the linear regression model
# <p>The variance looks much better now. Notice that now <code>Time (months)</code> has the largest variance, but it's not the <a href="https://en.wikipedia.org/wiki/Order_of_magnitude">orders of magnitude</a> higher than the rest of the variables, so we'll leave it as is.</p>
# <p>We are now ready to train the linear regression model.</p>

# %%
# Importing modules
from sklearn import linear_model

# Instantiate LogisticRegression
logreg = linear_model.LogisticRegression(
    solver='liblinear',
    random_state=42
)

# Train the model
logreg.fit(X_train_normed, y_train)

# AUC score for tpot model
logreg_auc_score = roc_auc_score(y_test, logreg.predict_proba(X_test_normed)[:, 1])
print(f'\nAUC score: {logreg_auc_score:.4f}')
# Out:
# AUC score: 0.7890

# %% [markdown]
# ## 11. Conclusion
# <p>The demand for blood fluctuates throughout the year. As one <a href="https://www.kjrh.com/news/local-news/red-cross-in-blood-donation-crisis">prominent</a> example, blood donations slow down during busy holiday seasons. An accurate forecast for the future supply of blood allows for an appropriate action to be taken ahead of time and therefore saving more lives.</p>
# <p>In this notebook, we explored automatic model selection using TPOT and AUC score we got was 0.7850. This is better than simply choosing <code>0</code> all the time (the target incidence suggests that such a model would have 76% success rate). We then log normalized our training data and improved the AUC score by 0.5%. In the field of machine learning, even small improvements in accuracy can be important, depending on the purpose.</p>
# <p>Another benefit of using logistic regression model is that it is interpretable. We can analyze how much of the variance in the response variable (<code>target</code>) can be explained by other variables in our dataset.</p>

# %%
# Importing itemgetter
from operator import itemgetter

# Sort models based on their AUC score from highest to lowest
sorted(
    [('tpot', tpot_auc_score), ('logreg', logreg_auc_score)],
    key=itemgetter(1),
    reverse=True
)
# Out:
# [('logreg', np.float64(0.7890178003814368)),
#  ('tpot', np.float64(0.7669262555626192))]
